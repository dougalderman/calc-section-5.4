# %%
#Problem 1

# %%
x = var('x')

# %%
def f(x): return (1/4)*x

# %%
p = []

# %%
p.append(plot(f(x),(x,0,1), color='blue', legend_label='f(x)'))

# %%
p.append(plot(f(x),(x,1,3), fill=true, color='blue'))

# %%
p.append(plot(f(x),(x,3,5), color='blue'))

# %%
sum(p)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
int = integral(f(x), x, 1, 3)

# %%
int
# Out:
# 1

# %% [markdown]
# ---

# %%
#Problem 5

# %%
x = var('x')

# %%
def f(x): return (3/64)*x^2

# %%
p = []

# %%
p.append(plot(f(x),(x,0,4), color='blue', fill=true, legend_label='f(x)'))

# %%
p.append(plot(f(x),(x,4,6), color='blue'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
int = integral(f(x), x, 0, 4)

# %%
int
# Out:
# 1

# %% [markdown]
# ---

# %%
#Problem 9

# %%
x = var('x')

# %%
def f(x): return (3/2)*x^2

# %%
p = []

# %%
p.append(plot(f(x),(x,-2,-1), color='blue', legend_label='f(x)'))

# %%
p.append(plot(f(x),(x,-1,1), color='blue', fill=true))

# %%
p.append(plot(f(x),(x,1,2), color='blue'))

# %%
sum(p)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
int = integral(f(x), x, -1, 1)

# %%
int
# Out:
# 1
